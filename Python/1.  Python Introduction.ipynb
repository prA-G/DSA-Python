# %% [markdown]
# # What is Programming?
#
# Programming means telling a computer what to do, step by step, using a language it understands.
#
# - Computer runs very fast but not smart, Requires instructions from user to perform any task. These instructions are written using a programming language.

# %% [markdown]
# # What is Python?
#
# Python is a high-level programming language.
# - That means:
#     - Easy to read
#     - Less confusing symbols
#     - Very beginner friendly
# - Python is used in:
#     - Web Developement
#     - Data Sceince
#     - Machine Learning
#     - Automation

# %% [markdown]
# # Python Code

# %%
print("Hello , World!!")
# Out:
# Hello , World!!

# %% [markdown]
# - `print` : Pythoon built-in function
# - () : Used to pass infromation to a function
# - "Hello , World!!" : A String text
# - Output : Display text on the screen

# %% [markdown]
# # Complexity
#
# ### Time complexity
# - Always takes the same time  : O(1)
#
# ### Space complexity
# - Uses very little memory : O(1)

# %% [markdown]
# # Common Interview questions

# %% [markdown]
# 1. What is python?
#
# Python is a high level, interpreted, easy to read programming language.
#
# 2. Why is Python popular?
#
# Simple syntax, huge libraries, used in many fields.
#
# 3. Is Python compiled or interpreted?
#
# Interpreted (Executed line by line)
#
# 4. What is `print()` function used for?
#
# To display output on the screen.
